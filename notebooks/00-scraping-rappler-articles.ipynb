# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup 
import time

# %% [markdown]
# # Scraping the data

# %%
# get total number of pages
api_url = 'https://rappler.com/wp-json/wp/v2/posts?page=1&per_page=100&after=2022-01-01T00:00:00'

response = requests.get(api_url)
pages_count = response.headers['X-WP-TotalPages']
n = int(pages_count)

print(f'Total number of pages: {n}')
# Out:
# Total number of pages: 226

# %%
# trial run, get posts
r = requests.get('http://rappler.com/wp-json/wp/v2/posts',
                     params={'after': '2022-01-01 00:00:00.000'}
                ).json()

sample = pd.json_normalize(r)
display(sample)
# Out:
#         id                 date             date_gmt             modified  \
# 0  2175355  2022-12-06T12:22:09  2022-12-06T04:22:09  2022-12-06T12:22:14
# 1  2175255  2022-12-06T12:19:19  2022-12-06T04:19:19  2022-12-06T12:19:26
# 2  2175328  2022-12-06T12:15:00  2022-12-06T04:15:00  2022-12-06T11:47:29
# 3  2175333  2022-12-06T12:07:18  2022-12-06T04:07:18  2022-12-06T12:07:24
# 4  2175298  2022-12-06T11:57:09  2022-12-06T03:57:09  2022-12-06T11:57:14
# 5  2175306  2022-12-06T11:53:50  2022-12-06T03:53:50  2022-12-06T11:53:57
# 6  2175318  2022-12-06T11:35:43  2022-12-06T03:35:43  2022-12-06T11:35:47
# 7  2175316  2022-12-06T11:34:39  2022-12-06T03:34:39  2022-12-06T11:34:48
# 8  2175288  2022-12-06T11:32:39  2022-12-06T03:32:39  2022-12-06T11:32:44
# 9  2174965  2022-12-06T11:08:51  2022-12-06T03:08:51  2022-12-06T11:09:00
#
#           modified_gmt                                               slug  \
# 0  2022-12-06T04:22:14  microsoft-offers-sony-contract-call-of-duty-pl...
# 1  2022-12-06T04:19:26   marcos-jr-adviser-paul-soriano-reach-out-critics
# 2  2022-12-06T03:47:29  game-results-boston-celtics-toronto-raptors-de...
# 3  2022-12-06T04:07:24  australia-says-law-facebook-google-pay-news-wo...
# 4  2022-12-06T03:57:14  bighit-music-announces-no-official-event-bts-j...
# 5  2022-12-06T03:53:57  herlene-nicole-budol-national-costume-for-miss...
# 6  2022-12-06T03:35:47  game-results-los-angeles-clippers-charlotte-ho...
# 7  2022-12-06T03:34:48             china-covid-19-updates-december-6-2022
# 8  2022-12-06T03:32:44  elon-musk-neuralink-faces-federal-employee-bac...
# 9  2022-12-06T03:09:00            bulacan-rescuer-narciso-calayag-profile
#
#     status  type                                               link  \
# 0  publish  post  https://www.rappler.com/technology/microsoft-o...
# 1  publish  post  https://www.rappler.com/newsbreak/inside-track...
# 2  publish  post  https://www.rappler.com/sports/nba/game-result...
# 3  publish  post  https://www.rappler.com/technology/australia-s...
# 4  publish  post  https://www.rappler.com/entertainment/celebrit...
# 5  publish  post  https://www.rappler.com/entertainment/pageants...
# 6  publish  post  https://www.rappler.com/sports/nba/game-result...
# 7  publish  post  https://www.rappler.com/world/asia-pacific/chi...
# 8  publish  post  https://www.rappler.com/technology/elon-musk-n...
# 9  publish  post  https://www.rappler.com/nation/luzon/bulacan-r...
#
#    featured_media  ...                                        _links.self  \
# 0         2175362  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 1         2175299  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 2         2175331  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 3         2081665  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 4         2175303  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 5         2175311  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 6         2175323  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 7         2175321  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 8         2175308  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 9         2175046  ...  [{'href': 'https://www.rappler.com/wp-json/wp/...
#
#                                    _links.collection  \
# 0  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 1  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 2  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 3  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 4  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 5  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 6  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 7  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 8  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 9  [{'href': 'https://www.rappler.com/wp-json/wp/...
#
#                                         _links.about  \
# 0  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 1  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 2  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 3  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 4  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 5  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 6  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 7  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 8  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 9  [{'href': 'https://www.rappler.com/wp-json/wp/...
#
#                                       _links.replies  \
# 0  [{'embeddable': True, 'href': 'https://www.rap...
# 1  [{'embeddable': True, 'href': 'https://www.rap...
# 2  [{'embeddable': True, 'href': 'https://www.rap...
# 3  [{'embeddable': True, 'href': 'https://www.rap...
# 4  [{'embeddable': True, 'href': 'https://www.rap...
# 5  [{'embeddable': True, 'href': 'https://www.rap...
# 6  [{'embeddable': True, 'href': 'https://www.rap...
# 7  [{'embeddable': True, 'href': 'https://www.rap...
# 8  [{'embeddable': True, 'href': 'https://www.rap...
# 9  [{'embeddable': True, 'href': 'https://www.rap...
#
#                               _links.version-history  \
# 0  [{'count': 2, 'href': 'https://www.rappler.com...
# 1  [{'count': 13, 'href': 'https://www.rappler.co...
# 2  [{'count': 1, 'href': 'https://www.rappler.com...
# 3  [{'count': 2, 'href': 'https://www.rappler.com...
# 4  [{'count': 2, 'href': 'https://www.rappler.com...
# 5  [{'count': 2, 'href': 'https://www.rappler.com...
# 6  [{'count': 3, 'href': 'https://www.rappler.com...
# 7  [{'count': 1, 'href': 'https://www.rappler.com...
# 8  [{'count': 3, 'href': 'https://www.rappler.com...
# 9  [{'count': 14, 'href': 'https://www.rappler.co...
#
#                           _links.predecessor-version  \
# 0  [{'id': 2175372, 'href': 'https://www.rappler....
# 1  [{'id': 2175367, 'href': 'https://www.rappler....
# 2  [{'id': 2175336, 'href': 'https://www.rappler....
# 3  [{'id': 2175354, 'href': 'https://www.rappler....
# 4  [{'id': 2175349, 'href': 'https://www.rappler....
# 5  [{'id': 2175344, 'href': 'https://www.rappler....
# 6  [{'id': 2175327, 'href': 'https://www.rappler....
# 7  [{'id': 2175324, 'href': 'https://www.rappler....
# 8  [{'id': 2175322, 'href': 'https://www.rappler....
# 9  [{'id': 2175305, 'href': 'https://www.rappler....
#
#                              _links.wp:featuredmedia  \
# 0  [{'embeddable': True, 'href': 'https://www.rap...
# 1  [{'embeddable': True, 'href': 'https://www.rap...
# 2  [{'embeddable': True, 'href': 'https://www.rap...
# 3  [{'embeddable': True, 'href': 'https://www.rap...
# 4  [{'embeddable': True, 'href': 'https://www.rap...
# 5  [{'embeddable': True, 'href': 'https://www.rap...
# 6  [{'embeddable': True, 'href': 'https://www.rap...
# 7  [{'embeddable': True, 'href': 'https://www.rap...
# 8  [{'embeddable': True, 'href': 'https://www.rap...
# 9  [{'embeddable': True, 'href': 'https://www.rap...
#
#                                 _links.wp:attachment  \
# 0  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 1  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 2  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 3  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 4  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 5  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 6  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 7  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 8  [{'href': 'https://www.rappler.com/wp-json/wp/...
# 9  [{'href': 'https://www.rappler.com/wp-json/wp/...
#
#                                       _links.wp:term  \
# 0  [{'taxonomy': 'category', 'embeddable': True, ...
# 1  [{'taxonomy': 'category', 'embeddable': True, ...
# 2  [{'taxonomy': 'category', 'embeddable': True, ...
# 3  [{'taxonomy': 'category', 'embeddable': True, ...
# 4  [{'taxonomy': 'category', 'embeddable': True, ...
# 5  [{'taxonomy': 'category', 'embeddable': True, ...
# 6  [{'taxonomy': 'category', 'embeddable': True, ...
# 7  [{'taxonomy': 'category', 'embeddable': True, ...
# 8  [{'taxonomy': 'category', 'embeddable': True, ...
# 9  [{'taxonomy': 'category', 'embeddable': True, ...
#
#                                        _links.curies
# 0  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 1  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 2  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 3  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 4  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 5  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 6  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 7  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 8  [{'name': 'wp', 'href': 'https://api.w.org/{re...
# 9  [{'name': 'wp', 'href': 'https://api.w.org/{re...
#
# [10 rows x 65 columns]

# %%
sample['title.rendered']
# Out:
# 0    Microsoft offers Sony 10-year contract for &#8...
# 1    Marcos adviser Paul Soriano wants to reach out...
# 2    Tatum, Brown-led Celtics edge Raptors, win 16 ...
# 3    Australia says law making Facebook and Google ...
# 4    BTS’ Jin’s enlistment will have no official ev...
# 5    LOOK: This is Herlene Budol’s national costume...
# 6    Kawhi Leonard late shots lift Clippers past Ho...
# 7    Chinese capital prepares for &#8216;life again...
# 8    Musk’s Neuralink faces federal probe, employee...
# 9    Bulacan rescuer Narciso ‘Ona’ Calayag: Dreamer...
# Name: title.rendered, dtype: object

# %%
# loop over the different pages
data = list()
current_page = 1

while current_page <= n:
    print(f'Scraping page: {current_page}...')
    r = requests.get('http://rappler.com/wp-json/wp/v2/posts',
                     params={'after': '2022-01-01 00:00:00.000',
                             'page': current_page,
                             'per_page':100}).json()
    data.extend(r)
    current_page += 1
    time.sleep(np.random.randint(2,5))

# %%
df = pd.json_normalize(data)
df[df.duplicated('id', keep=False)].sort_values('id')

# %%
df.drop_duplicates('id', keep='first', inplace=True)
# df.to_csv('2022-rappler-articles.csv', index=False)

# %% [markdown]
# # Filtering data for processing

# %%
df = pd.read_csv('2022-rappler-articles.csv')
df.shape

# %%
drop_features = ['prepublish_checks.xbs-valid-conversions.status',
       'prepublish_checks.xbs-valid-conversions.message',
       'prepublish_checks.xbs-valid-conversions.data',
       'prepublish_checks.xbs-valid-fallback.status',
       'prepublish_checks.xbs-valid-fallback.message',
       'prepublish_checks.xbs-valid-fallback.data', 'ab_tests.titles.started',
       'ab_tests.titles.start_time', 'ab_tests.titles.end_time',
       'ab_tests.titles.traffic_percentage',
       'ab_tests.titles.variant_traffic_percentage', 'ab_tests.titles.paused',
       'ab_tests.featured_images.started',
       'ab_tests.featured_images.start_time',
       'ab_tests.featured_images.end_time',
       'ab_tests.featured_images.traffic_percentage',
       'ab_tests.featured_images.variant_traffic_percentage',
       'ab_tests.featured_images.paused', '_links.self', '_links.collection',
       '_links.about', '_links.replies', '_links.version-history',
       '_links.predecessor-version', '_links.wp:featuredmedia',
       '_links.wp:attachment', '_links.wp:term', '_links.curies', 'meta.claim_author_type',
       'meta.claim_author_name', 'meta.claim_reviewed', 'meta.review_rating',
       'meta.schema_article_type', 'template', 'status', 'type', 'ab_test_titles',
       'ab_test_featured_images', 'sticky', 'format', 'content.protected', 'excerpt.protected'         
                ]

df.drop(columns=drop_features, inplace=True)

# %%
df['title.rendered'] = df['title.rendered'].apply(lambda x: BeautifulSoup(x).text)
df['content.rendered'] = df['content.rendered'].apply(lambda x: BeautifulSoup(x).string.strip())
df['content.rendered'] = df['content.rendered'].str.replace('\n',' ')

# %%
rel_cols = ['id', 'date', 'link', 'title.rendered', 'content.rendered']
df[rel_cols].to_csv('2022-rappler-articles-clean.csv', index=False)
